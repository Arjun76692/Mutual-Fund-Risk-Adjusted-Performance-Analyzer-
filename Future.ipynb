# %%
from mftool import Mftool
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
import pandas as pd

# %%
mf=Mftool()

# %%
df=mf.get_scheme_historical_nav(120586,as_Dataframe=True)

# %%
df
# Out:
#                   nav  dayChange
# date
# 13-02-2026  124.37000      -1.35
# 12-02-2026  125.72000      -0.54
# 11-02-2026  126.26000       0.04
# 10-02-2026  126.22000       0.37
# 09-02-2026  125.85000       0.40
# ...               ...        ...
# 08-01-2013   18.76000       0.04
# 07-01-2013   18.72000      -0.04
# 04-01-2013   18.76000       0.03
# 03-01-2013   18.73000       0.07
# 02-01-2013   18.66000        NaN
#
# [3228 rows x 2 columns]

# %%
print(mf.get_scheme_details('120586'))
# Out:
# {'fund_house': 'ICICI Prudential Mutual Fund', 'scheme_type': 'Open Ended Schemes', 'scheme_category': 'Equity Scheme - Large Cap Fund', 'scheme_code': 120586, 'scheme_name': 'ICICI Prudential Large Cap Fund (erstwhile Bluechip Fund) - Direct Plan - Growth', 'scheme_start_date': {'date': '02-01-2013', 'nav': '18.66000'}}

# %%
df.columns
df.reset_index(inplace=True)

df.columns
# Out:
# Index(['date', 'nav', 'dayChange'], dtype='object')

# %%
df.sort_values(by='date',ascending=True,inplace=True)
df.reset_index(drop=True,inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3228 entries, 0 to 3227
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   date       3228 non-null   object
#  1   nav        3228 non-null   object
#  2   dayChange  3227 non-null   float64
# dtypes: float64(1), object(2)
# memory usage: 75.8+ KB

# %%
df['nav']=df.nav.astype('float')
df['date']=pd.to_datetime(df.date,dayfirst=True)
df.info()
df['change_pct']=(df['nav'].pct_change().round(2))*100
df
df.change_pct.describe()
df.count(0)-df[df.change_pct>df['change_pct'].quantile(0.75)].count(0)['nav']+df[df.change_pct<df['change_pct'].quantile(0.25)].count(0)['nav']
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3228 entries, 0 to 3227
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   date       3228 non-null   datetime64[ns]
#  1   nav        3228 non-null   float64
#  2   dayChange  3227 non-null   float64
# dtypes: datetime64[ns](1), float64(2)
# memory usage: 75.8 KB
# date          3210
# nav           3210
# dayChange     3209
# change_pct    3209
# dtype: int64

# %%
# df['change_fromprev']=df['nav'].pct_change()
# df

# %%
mf.get_available_schemes("ICICI")
# Out:
# {'112343': 'ICICI Prudential Banking and PSU Debt Fund -  Daily IDCW',
#  '112344': 'ICICI Prudential Banking and PSU Debt Fund -  Weekly IDCW',
#  '130897': 'ICICI Prudential Banking and PSU Debt Fund - Bonus',
#  '120257': 'ICICI Prudential Banking and PSU Debt Fund - Direct Plan -  Daily IDCW',
#  '120256': 'ICICI Prudential Banking and PSU Debt Fund - Direct Plan -  Growth',
#  '120258': 'ICICI Prudential Banking and PSU Debt Fund - Direct Plan -  Quarterly IDCW',
#  '120255': 'ICICI Prudential Banking and PSU Debt Fund - Direct Plan -  Weekly IDCW',
#  '130950': 'ICICI Prudential Banking and PSU Debt Fund - Direct Plan Bonus',
#  '131148': 'ICICI Prudential Banking and PSU Debt Fund - Direct Plan Half Yearly IDCW Option',
#  '112342': 'ICICI Prudential Banking and PSU Debt Fund - Growth',
#  '116174': 'ICICI Prudential Banking and PSU Debt Fund - Quarterly IDCW',
#  '131147': 'ICICI Prudential Banking and PSU Debt Fund Half Yearly IDCW Option',
# ...
